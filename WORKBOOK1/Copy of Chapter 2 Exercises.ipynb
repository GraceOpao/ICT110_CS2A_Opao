# %% [markdown]
# Chapter 2 Exercises

# %% [markdown]
# Exercise 1

# %%
name = input('Enter your name: ')
print('Hello', name)
# Out:
# Enter your name: Mama
# Hello Mama

# %% [markdown]
# EXERCISE 2

# %%
float_hours = float(input('Enter Hours: '))
float_rate = float(input('Enter rate:'))
pay = (float_hours*float_rate)
print("Pay:", pay)
# Out:
# Enter Hours: 1
# Enter rate:23
# Pay: 23.0

# %% [markdown]
# EXERCISE 3

# %%
width = 17
height = 12.0

result1 = width // 2
print("Result 1:", result1, "Type:", type(result1))

result2 = width / 2.0
print("Result 2:", result2, "Type:", type(result2))

result3 = height / 3
print("Result 3:", result3, "Type:", type(result3))

result4 = 1 + 2 * 5
print("Result 4:", result4, "Type:", type(result4))
# Out:
# Result 1: 8 Type: <class 'int'>
# Result 2: 8.5 Type: <class 'float'>
# Result 3: 4.0 Type: <class 'float'>
# Result 4: 11 Type: <class 'int'>

# %% [markdown]
# EXERCISE 4

# %%
number = float (input("Enter number: "))
square = number * number
print(f"the square of {number} is {square}")
# Out:
# Enter number: 12
# the square of 12.0 is 144.0

# %% [markdown]
# CHALLENGE

# %%
celsius = int (input("Enter Celsius: "))
fahrenheit = (celsius * (9/5)) + 32
print (celsius, "celsius is", fahrenheit, "in fahrenheit")
# Out:
# Enter Celsius: 12
# 12 celsius is 53.6 in fahrenheit
